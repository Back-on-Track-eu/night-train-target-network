# %%
import requests, json

# %%
resp = requests.post(
    "https://www.trassenfinder.de/api/web/infrastrukturen/45/suchen",
    json={
        "startBetriebsstelle": "BLS",
        "zielBetriebsstelle": "MH",
        "wagenzugmasse": 800,
        "streckenklasse": "D4",
        "triebfahrzeugtyp": "BR 193.2"
    }
)
print(json.dumps(resp.json(), indent=2))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\Documents\GitHub\night-train-target-network\backend\.venv\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...
